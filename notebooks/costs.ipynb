# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sns
from datetime import datetime
from scipy.stats import gmean
from typing import Optional, Tuple
import sys
import os

# add the parent directory to the path to import from src
parent_dir = os.path.dirname(os.getcwd())
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# import the algorithm components directly
from src.algorithm import (
    TensorNetwork, 
    evaluate_config, 
    update_edge, 
    estimate_contraction, 
    run_multiple_chains,
    contract_tensor_network
)

EPS = 1e-12
def gmean_series(s):
    x = np.clip(s.to_numpy(np.float64), EPS, None)
    return float(np.exp(np.mean(np.log(x))))

def gvar_series(s):
    x = np.clip(s.to_numpy(np.float64), EPS, None)
    return float(np.var(np.log(x), ddof=1))

def gstd_series(s):
    x = np.clip(s.to_numpy(np.float64), EPS, None)
    return float(np.std(np.log(x), ddof=1)) # dont exp, log 10

# %%
# A = len(beta) = number of beta ladder steps
# B = n_chains = number of parallel random walks  
# C = iters = number of Glauber updates per chain per beta step

import pandas as pd
from itertools import product
import time

def create_test_tensor_network(network_type="2x2_ring", dim=3, seed=42):
    np.random.seed(seed)
    
    if network_type == "2x2_ring":
        G = nx.Graph()
        G.add_edges_from([('A', 'B'), ('B', 'C'), ('C', 'D'), ('D', 'A')])
        
        tensors = {}
        index_order = {'A': ['i', 'j'], 'B': ['j', 'k'], 'C': ['k', 'l'], 'D': ['l', 'i']}
        
        for node, inds in index_order.items():
            data = np.random.normal(loc=1.0, scale=0.1, size=(dim, dim)) + 1e-6 #uniform around 1
            tensors[node] = (data, inds)
        
        # compute exact value
        A, B, C, D = [tensors[k][0] for k in ['A', 'B', 'C', 'D']]
        Z_true = np.einsum('ij,jk,kl,li->', A, B, C, D)
        
    elif network_type == "3x3_grid":
        G = nx.Graph()
        tensors = {}
        grid_size = 3
        node_names = {(i, j): f"T{i}{j}" for i in range(grid_size) for j in range(grid_size)}
        
        def edge_index(i1, j1, i2, j2):
            return f"{i1}{j1}_{i2}{j2}"
            
        for i in range(grid_size):
            for j in range(grid_size):
                name = node_names[(i, j)]
                neighbors = []
                
                if j + 1 < grid_size:
                    neighbors.append(edge_index(i, j, i, j+1))
                    G.add_edge(name, node_names[(i, j+1)])
                if i + 1 < grid_size:
                    neighbors.append(edge_index(i, j, i+1, j))
                    G.add_edge(name, node_names[(i+1, j)])
                if j > 0:
                    neighbors.append(edge_index(i, j-1, i, j))
                if i > 0:
                    neighbors.append(edge_index(i-1, j, i, j))
                    
                neighbors = sorted(neighbors)
                shape = (dim,) * len(neighbors)
                data = np.random.rand(*shape) + 1e-6
                tensors[name] = (data, neighbors)
        
        # for 3x3 grid, exact computation is expensive, so we'll use a reference run
        Z_true = None
    
    tn = TensorNetwork(G, tensors)
    return tn, Z_true


def run_ais_experiment(tn, A, B, C, seed=None, verbose=False, return_time=True):
    if seed is not None:
        np.random.seed(int(seed))
    betas = np.linspace(0, 1, A)
    # betas = 1 - np.exp(-np.linspace(0, 4, A))
    
    start_time = time.time() if return_time else None
    
    # run AIS
    Z_est, Z_std = run_multiple_chains(
        tn, betas, 
        iters=C, 
        burns=min(C//10, C-1),  # 10% burn-in, but at least leave 1 sample
        n_chains=B, 
        verbose=verbose
    )
    
    end_time = time.time() if return_time else None
    wall_time = (end_time - start_time) if return_time else None
    
    return {
        'Z_est': Z_est,
        'Z_std': Z_std, 
        'time_seconds': wall_time,
        'A': A, 'B': B, 'C': C,
        'N': A * B * C
    }


def compute_relative_error(Z_est, Z_true):
    if Z_true is None:
        return np.nan
    return abs(Z_est - Z_true) / abs(Z_true)


def generate_cost_experiment_data(tn, N_values, A_range, B_range, Z_true=None,
                                 n_trials=10, seeds=None, reseed_network=False, verbose=True):
    results = []
    if seeds is None:
        seeds = list(range(n_trials))  # backward compatible

    total = len(N_values)*len(A_range)*len(B_range)*len(seeds)
    count = 0

    base_tn = tn  # keep a copy if we want fixed network

    for N in N_values:
        for A in A_range:
            for B in B_range:
                if N % (A*B) != 0:  # C must be integer
                    continue
                C = N // (A*B)
                if C < 1:
                    continue

                for seed in seeds:
                    count += 1
                    if verbose and count % 10 == 0:
                        print(f"progress: {count}/{total} (N={N}, A={A}, B={B}, C={C}, seed={seed})")

                    tn_used = base_tn
                    if reseed_network:
                        tn_used, _ = create_test_tensor_network("2x2_ring", dim=3, seed=seed)

                    out = run_ais_experiment(tn_used, A, B, C, seed=seed, verbose=False)
                    rel_err = compute_relative_error(out['Z_est'], Z_true)

                    results.append({
                        'N': N, 'A': A, 'B': B, 'C': C, 'seed': seed,
                        'Z_est': out['Z_est'], 'Z_std': out['Z_std'],
                        'rel_error': rel_err, 'time_seconds': out['time_seconds']
                    })

    return pd.DataFrame(results)



def plot_cost_heatmap(df, N_value, metric='rel_error', aggregation='gmean'):
    data = df[df['N'] == N_value].copy()
    
    if data.empty:
        print(f"No data for N={N_value}")
        return
    
    # aggregate across trials
    if aggregation == 'mean':
        agg_data = data.groupby(['A', 'B'])[metric].mean().reset_index()
    elif aggregation == 'median':
        agg_data = data.groupby(['A', 'B'])[metric].median().reset_index()
    elif aggregation == 'min':
        agg_data = data.groupby(['A', 'B'])[metric].min().reset_index()
    elif aggregation == 'gmean': 
        agg = data.groupby(['A','B'])[metric].apply(gmean_series)
        agg_data = agg.reset_index(name=metric)
    else:
        raise ValueError(f"Unknown aggregation: {aggregation}")

    
    pivot = agg_data.pivot(index='A', columns='B', values=metric)
    C_pivot = data.groupby(['A', 'B'])['C'].first().reset_index().pivot(index='A', columns='B', values='C')
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    # main metric heatmap
    sns.heatmap(pivot, annot=True, fmt='.2e' if metric == 'rel_error' else '.2f', 
                cmap='viridis', ax=ax1)
    ax1.set_title(f'{metric.replace("_", " ").title()} ({aggregation})\nN = {N_value}')
    ax1.set_xlabel('B (number of chains)')
    ax1.set_ylabel('A (beta ladder length)')
    
    # C values heatmap  
    sns.heatmap(C_pivot, annot=True, fmt='d', cmap='Blues', ax=ax2)
    ax2.set_title(f'Corresponding C values\n(iterations per chain per beta)')
    ax2.set_xlabel('B (number of chains)')
    ax2.set_ylabel('A (beta ladder length)')
    
    plt.tight_layout()
    plt.show()

def plot_variance_heatmap(df, N_value, metric='rel_error', mode='logvar'):
    data = df[df['N'] == N_value].copy()
    if data.empty:
        print(f"No data for N={N_value}")
        return
    
    if mode == 'logvar':
        agg = data.groupby(['A','B'])[metric].apply(gvar_series).reset_index(name='logvar')
        values = agg.pivot(index='A', columns='B', values='logvar')
        title = 'Variance of log(Rel Error)'
        fmt = '.2e'
        cmap = 'magma'
    elif mode == 'gstd':
        agg = data.groupby(['A','B'])[metric].apply(gstd_series).reset_index(name='gstd')
        values = agg.pivot(index='A', columns='B', values='gstd')
        title = 'Geometric Std Dev of Rel Error'
        fmt = '.2f'
        cmap = 'magma_r'
    else:
        raise ValueError(f"Unknown mode: {mode}")
    
    C_pivot = data.groupby(['A', 'B'])['C'].first().reset_index().pivot(index='A', columns='B', values='C')

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    sns.heatmap(values, annot=True, fmt=fmt, cmap=cmap, ax=ax1)
    ax1.set_title(f'{title}\nN = {N_value}')
    ax1.set_xlabel('B (number of chains)'); ax1.set_ylabel('A (beta ladder length)')

    sns.heatmap(C_pivot, annot=True, fmt='d', cmap='Blues', ax=ax2)
    ax2.set_title('Corresponding C values\n(iterations per chain per beta)')
    ax2.set_xlabel('B (number of chains)'); ax2.set_ylabel('A (beta ladder length)')
    plt.tight_layout(); plt.show()

# %%
tn, Z_true = create_test_tensor_network("3x3_grid", dim=3, seed=42)
if Z_true is None:
    print('computing reference Z_true via exact contraction...')
    Z_true = contract_tensor_network(tn.graph, tn.tensors)
print(f"true contraction Z = {Z_true:.6f}")

N_values = [100000] 

A_range = [5, 10, 20, 25, 50]  # beta ladder lengths
B_range = [5, 10, 20, 25, 50, 100, 200]  # number of chains

print(f"\nparameter ranges:")
print(f"N = {N_values}")
print(f"A (beta steps) = {A_range}")
print(f"B (chains) = {B_range}")

# show what C values we'll get
print(f"\npossible (A,B,C) combinations for N={N_values[0]}:")
valid_combinations = []
for A in A_range:
    for B in B_range:
        if N_values[0] % (A * B) == 0:
            C = N_values[0] // (A * B)
            if C >= 1:
                valid_combinations.append((A, B, C))
                print(f"  A={A:2d}, B={B:3d}, C={C:4d}")

print(f"\ntotal valid combinations: {len(valid_combinations)}")
# Out:
# computing reference Z_true via exact contraction...
# true contraction Z = 649.220442
#
# parameter ranges:
# N = [100000]
# A (beta steps) = [5, 10, 20, 25, 50]
# B (chains) = [5, 10, 20, 25, 50, 100, 200]
#
# possible (A,B,C) combinations for N=100000:
#   A= 5, B=  5, C=4000
#   A= 5, B= 10, C=2000
#   A= 5, B= 20, C=1000
#   A= 5, B= 25, C= 800
#   A= 5, B= 50, C= 400
#   A= 5, B=100, C= 200
#   A= 5, B=200, C= 100
#   A=10, B=  5, C=2000
#   A=10, B= 10, C=1000
#   A=10, B= 20, C= 500
#   A=10, B= 25, C= 400
#   A=10, B= 50, C= 200
#   A=10, B=100, C= 100
#   A=10, B=200, C=  50
#   A=20, B=  5, C=1000
#   A=20, B= 10, C= 500
#   A=20, B= 20, C= 250
#   A=20, B= 25, C= 200
#   A=20, B= 50, C= 100
#   A=20, B=100, C=  50
#   A=20, B=200, C=  25
#   A=25, B=  5, C= 800
#   A=25, B= 10, C= 400
#   A=25, B= 20, C= 200
#   A=25, B= 25, C= 160
#   A=25, B= 50, C=  80
#   A=25, B=100, C=  40
#   A=25, B=200, C=  20
#   A=50, B=  5, C= 400
#   A=50, B= 10, C= 200
#   A=50, B= 20, C= 100
#   A=50, B= 25, C=  80
#   A=50, B= 50, C=  40
#   A=50, B=100, C=  20
#   A=50, B=200, C=  10
#
# total valid combinations: 35

# %%
print(f"running {len(valid_combinations)} combinations over 3 trials = {len(valid_combinations) * 3} total experiments")

start_time = time.time()
results_df = generate_cost_experiment_data(
    tn=tn, 
    N_values=N_values, 
    A_range=A_range, 
    B_range=B_range, 
    Z_true=Z_true,
    n_trials=3,  # start with 3 trials

    verbose=True
)
end_time = time.time()

print(f"\nexperiments completed in {end_time - start_time:.1f} seconds")
print(f"generated {len(results_df)} data points")

print(f"\nsummary stats:")
print(f"relative error range: {results_df['rel_error'].min():.2e} to {results_df['rel_error'].max():.2e}")
overall_gm = gmean_series(results_df['rel_error'].dropna())
print(f"geometric mean relative error: {overall_gm:.2e}")
print(f"time per experiment: {results_df['time_seconds'].mean():.3f} +/- {results_df['time_seconds'].std():.3f} seconds")

results_df.to_csv('cost_optimization_N100k.csv', index=False)
# Out:
# running 35 combinations over 3 trials = 105 total experiments
# progress: 10/105 (N=100000, A=5, B=25, C=800, seed=0)
# progress: 10/105 (N=100000, A=5, B=25, C=800, seed=0)
# progress: 20/105 (N=100000, A=5, B=200, C=100, seed=1)
# progress: 20/105 (N=100000, A=5, B=200, C=100, seed=1)
# progress: 30/105 (N=100000, A=10, B=20, C=500, seed=2)
# progress: 30/105 (N=100000, A=10, B=20, C=500, seed=2)
# progress: 40/105 (N=100000, A=10, B=200, C=50, seed=0)
# progress: 40/105 (N=100000, A=10, B=200, C=50, seed=0)
# progress: 50/105 (N=100000, A=20, B=20, C=250, seed=1)
# progress: 50/105 (N=100000, A=20, B=20, C=250, seed=1)
# progress: 60/105 (N=100000, A=20, B=100, C=50, seed=2)
# progress: 60/105 (N=100000, A=20, B=100, C=50, seed=2)
# progress: 70/105 (N=100000, A=25, B=20, C=200, seed=0)
# progress: 70/105 (N=100000, A=25, B=20, C=200, seed=0)
# progress: 80/105 (N=100000, A=25, B=100, C=40, seed=1)
# progress: 80/105 (N=100000, A=25, B=100, C=40, seed=1)
# progress: 90/105 (N=100000, A=50, B=10, C=200, seed=2)
# progress: 90/105 (N=100000, A=50, B=10, C=200, seed=2)
# progress: 100/105 (N=100000, A=50, B=100, C=20, seed=0)
# progress: 100/105 (N=100000, A=50, B=100, C=20, seed=0)
#
# experiments completed in 75.3 seconds
# generated 105 data points
#
# summary stats:
# relative error range: 2.14e-04 to 4.38e-01
# geometric mean relative error: 5.08e-02
# time per experiment: 0.717 +/- 0.123 seconds
#
# experiments completed in 75.3 seconds
# generated 105 data points
#
# summary stats:
# relative error range: 2.14e-04 to 4.38e-01
# geometric mean relative error: 5.08e-02
# time per experiment: 0.717 +/- 0.123 seconds

# %%
plot_cost_heatmap(results_df, N_value=100000, metric='rel_error', aggregation='gmean')
plot_variance_heatmap(results_df, N_value=100000, metric='rel_error', mode='logvar') # higher is worse
plot_variance_heatmap(results_df, N_value=100000, metric='rel_error', mode='gstd') # closer to 1 is better

# show the best performing combinations
gm  = results_df.groupby(['A','B'])['rel_error'].apply(gmean_series).reset_index(name='gm_rel_error')
gsv = results_df.groupby(['A','B'])['rel_error'].apply(gstd_series).reset_index(name='gstd_factor')
cnt = results_df.groupby(['A','B']).size().reset_index(name='count')

rank = gm.merge(gsv, on=['A','B']).merge(cnt, on=['A','B']).sort_values('gm_rel_error')

print("\nTop 5 best (A,B) by geometric mean error:")
for _, row in rank.head(5).iterrows():
    A, B = int(row['A']), int(row['B']); C = 100000 // (A*B)
    print(f"  A={A:2d}, B={B:3d}, C={C:4d} → gm_error={row['gm_rel_error']:.2e}, gstd×={row['gstd_factor']:.2f}, n={row['count']}")

print("\nWorst 5 combinations:")
for _, row in rank.tail(5).iterrows():
    A, B = int(row['A']), int(row['B']); C = 100000 // (A*B)
    print(f"  A={A:2d}, B={B:3d}, C={C:4d} → gm_error={row['gm_rel_error']:.2e}, gstd×={row['gstd_factor']:.2f}, n={row['count']}")


plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
# scatter plot of C vs relative error
scatter_data = results_df.groupby(['A', 'B', 'C'])['rel_error'].mean().reset_index()
plt.scatter(scatter_data['C'], scatter_data['rel_error'], alpha=0.7, 
           c=scatter_data['A'], cmap='viridis', s=50)
plt.colorbar(label='A (beta steps)')
plt.xlabel('C (iterations per chain per beta)')
plt.ylabel('mean relative error')
plt.yscale('log')
plt.title('error vs interation count')
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
# box plot showing error distribution for different A values
results_df.boxplot(column='rel_error', by='A', ax=plt.gca())
plt.yscale('log')
plt.title('error distribution by beta steps (A)')
plt.suptitle('') 
plt.ylabel('relative error')
plt.xlabel('A (beta ladder length)')

plt.tight_layout()
plt.show()
# Out:
# Top 5 best (A,B) by geometric mean error:
#   A=25, B= 50, C=  80 → gm_error=7.37e-03, gstd×=1.46, n=3.0
#   A=50, B=100, C=  20 → gm_error=8.91e-03, gstd×=0.68, n=3.0
#   A=50, B=200, C=  10 → gm_error=9.71e-03, gstd×=0.90, n=3.0
#   A=25, B=200, C=  20 → gm_error=9.94e-03, gstd×=1.48, n=3.0
#   A= 5, B= 50, C= 400 → gm_error=1.54e-02, gstd×=3.71, n=3.0
#
# Worst 5 combinations:
#   A=10, B= 20, C= 500 → gm_error=1.77e-01, gstd×=0.85, n=3.0
#   A= 5, B= 10, C=2000 → gm_error=2.18e-01, gstd×=0.63, n=3.0
#   A= 5, B=  5, C=4000 → gm_error=2.26e-01, gstd×=0.10, n=3.0
#   A= 5, B= 25, C= 800 → gm_error=2.74e-01, gstd×=0.35, n=3.0
#   A=10, B= 25, C= 400 → gm_error=3.03e-01, gstd×=0.50, n=3.0
